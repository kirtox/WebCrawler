# %% [markdown]
# # Web Crawler

# %% [markdown]
# ***

# %% [markdown]
# ## 用途
#  - 爬蟲是透過程式**自動抓取**網站資料的過程，在資訊量爆炸的現在，資料蒐集是一個相當重要的工作，如果依舊透過人工的方式來蒐集網站資料，除了效率差外還會浪費掉很多的時間。
#  - 因此就可以透過爬蟲協助，只要我們先定好規則，讓爬蟲來自動化蒐集與擷取資料，整理出我們所需要的內容。

# %% [markdown]
# ## 主要流程
# 1. 傳送GET請求給目標網站
# 2. 抓取所需資料
#     - 將HTML文件 **解析** 並 **擷取** 需要的資料
# 3. 儲存資料
#     - 將擷取整理過的資料儲存在CSV、Excel或是資料庫。

# %% [markdown]
# ## 使用工具
# 1. ***BeautifulSoup***: 用於解析網頁的套件
# 2. ***Selenium***: 用於抓取透過JavaScript產生的動態網頁的內容

# %% [markdown]
# ***

# %% [markdown]
# ## 安裝環境

# %% [markdown]
# ## ```pip install requests```
# ### 對網路發動請求的套件，可實作對網頁做get、post等HTTP協定的行為
#
# ## ```pip install beautifulsoup4```
# ### 借助網頁的結構特性來解析網頁的工具，只需要簡單的幾條指令就可以提取HTML標籤裡的元素

# %% [markdown]
# ***

# %% [markdown]
# ## 實作1: 爬取PTT八卦版的文章資訊

# %% [markdown]
# ### 以PTT八卦版為例 : https://www.ptt.cc/bbs/Gossiping/index.html

# %% [markdown]
# ### Step1. import 套件

# %%
import requests
from bs4 import BeautifulSoup

# 把Warning訊息去掉
requests.packages.urllib3.disable_warnings()

# %% [markdown]
# ***

# %% [markdown]
# ### Step2. 將網頁Get下來

# %%
# 設定proxy 在公司內需使用
http_proxy = "http://auhqproxy.corpnet.auo.com:8080/"
https_proxy = "http://auhqproxy.corpnet.auo.com:8080/"
ftp_proxy = "http://auhqproxy.corpnet.auo.com:8080/"

proxyDict = { 
              "http"  : http_proxy, 
              "https" : https_proxy, 
              "ftp"   : ftp_proxy
            }
            
#r = requests.get(url, proxies=proxyDict, verify=False)

# %%
# 要爬的網站
url = "https://www.ptt.cc/bbs/Gossiping/index.html"

# %% [markdown]
# ***

# %% [markdown]
# ### Step3. 處理PTT網站詢問是否已滿18歲的問題
# 1. 進入網站後會看到讓使用者點選「是否已滿18歲」按鈕
#
# 2. 可開啟瀏覽器開發者模式(F12)，並點選至network(網路)，觀察點選「已滿18歲」後，會送給伺服器之封包內容。
#
# 3. 發現封包以POST發送，並且封包內容有cookie和參數
#
# 4. 我們的程式碼可以透過POST的方式，送出cookie和特定的參數
#
# 5. 可以藉由requests的一個參數來儲存自身的cookie
#    Session會將你送出的requests所收到的cookies全部儲存起來並且在發送下一次請求時送出對應的參數。

# %%
# 處理是否已滿18歲的問題
payload = {
    "from":"/bbs/Gossiping/index.html",
    "yes":"yes"
}

rs = requests.session()

# 送出資訊已滿18歲的資訊
# verify=False 是為了避免SSL認證
res = rs.post("https://www.ptt.cc/ask/over18", proxies=proxyDict, verify=False, data=payload)

# 將此頁面的HTML GET下來
res = rs.get(url, proxies=proxyDict, verify=False)

# 印出HTML
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/challenge-platform/h/g/scripts/invisible.js?ts=1650610800'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39346.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Skyblueway</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				(本文已被刪除) [golang]
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">-</div>
# 				<div class="article-menu">
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">56</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mom10dollar</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E7%8D%A8%E5%AE%B6%EF%BD%9C%E6%AC%A020%E8%90%AC%E5%84%9F300%E8%90%AC%E9%82%84%E4%B8%8D%E5%A4%A0%EF%BC%81%E7%89%B9%E6%88%B0%E5%A3%AB%E5%AE%98%E4%B8%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amom10dollar">搜尋看板內 mom10dollar 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612732.A.426.html">[新聞] 「以篩代隔」隔離保單賠不賠？ 業者說</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">wbsinger</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E3%80%8C%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%E3%80%8D%E9%9A%94%E9%9B%A2%E4%BF%9D%E5%96%AE%E8%B3%A0%E4%B8%8D%E8%B3%A0%EF%BC%9F&#43;%E6%A5%AD%E8%80%85%E8%AA%AA">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Awbsinger">搜尋看板內 wbsinger 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612740.A.15A.html">[問卦] 養狗還是養小孩?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">snowsummersp</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%A4%8A%E7%8B%97%E9%82%84%E6%98%AF%E9%A4%8A%E5%B0%8F%E5%AD%A9%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Asnowsummersp">搜尋看板內 snowsummersp 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612824.A.CDE.html">Re: [問卦] 台灣的大學生到底在怕甚麼?????</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">papapapapapa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%8F%B0%E7%81%A3%E7%9A%84%E5%A4%A7%E5%AD%B8%E7%94%9F%E5%88%B0%E5%BA%95%E5%9C%A8%E6%80%95%E7%94%9A%E9%BA%BC%3F%3F%3F%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Apapapapapapa">搜尋看板內 papapapapapa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612863.A.F2F.html">[問卦] 用無人機外送可行嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ronnyvvang</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%94%A8%E7%84%A1%E4%BA%BA%E6%A9%9F%E5%A4%96%E9%80%81%E5%8F%AF%E8%A1%8C%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aronnyvvang">搜尋看板內 ronnyvvang 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">7</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612898.A.B1F.html">[問卦] 是不是要等年輕人死光了再來打疫苗?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">GoogleTaiwan</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%98%AF%E4%B8%8D%E6%98%AF%E8%A6%81%E7%AD%89%E5%B9%B4%E8%BC%95%E4%BA%BA%E6%AD%BB%E5%85%89%E4%BA%86%E5%86%8D%E4%BE%86%E6%89%93%E7%96%AB%E8%8B%97%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AGoogleTaiwan">搜尋看板內 GoogleTaiwan 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612930.A.705.html">Re: [爆卦] 本土+3766 類官方粗暴版本（轉）</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">devidevi</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E7%88%86%E5%8D%A6%5D&#43;%E6%9C%AC%E5%9C%9F%2B3766&#43;%E9%A1%9E%E5%AE%98%E6%96%B9%E7%B2%97%E6%9A%B4%E7%89%88%E6%9C%AC%EF%BC%88%E8%BD%89%EF%BC%89">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Adevidevi">搜尋看板內 devidevi 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612986.A.0A8.html">[新聞] 雙北逾3萬人居隔！打3劑｢以篩代隔｣擬擴</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">zenmeke</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E9%9B%99%E5%8C%97%E9%80%BE3%E8%90%AC%E4%BA%BA%E5%B1%85%E9%9A%94%EF%BC%81%E6%89%933%E5%8A%91%EF%BD%A2%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%EF%BD%A3%E6%93%AC%E6%93%B4">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Azenmeke">搜尋看板內 zenmeke 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650612998.A.5F5.html">Re: [問卦] 台鐵員工5/1憑啥以勞工名義合理罷工</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">alvptt</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%8F%B0%E9%90%B5%E5%93%A1%E5%B7%A55%2F1%E6%86%91%E5%95%A5%E4%BB%A5%E5%8B%9E%E5%B7%A5%E5%90%8D%E7%BE%A9%E5%90%88%E7%90%86%E7%BD%B7%E5%B7%A5">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalvptt">搜尋看板內 alvptt 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613014.A.663.html">[問卦] 何不用氣球將病患送醫跟送物資就好？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">TPAsavelove</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E4%BD%95%E4%B8%8D%E7%94%A8%E6%B0%A3%E7%90%83%E5%B0%87%E7%97%85%E6%82%A3%E9%80%81%E9%86%AB%E8%B7%9F%E9%80%81%E7%89%A9%E8%B3%87%E5%B0%B1%E5%A5%BD%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ATPAsavelove">搜尋看板內 TPAsavelove 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613015.A.431.html">[問卦] 老闆反應永遠慢半拍的八卦？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">SHERLOCKZH</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%80%81%E9%97%86%E5%8F%8D%E6%87%89%E6%B0%B8%E9%81%A0%E6%85%A2%E5%8D%8A%E6%8B%8D%E7%9A%84%E5%85%AB%E5%8D%A6%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ASHERLOCKZH">搜尋看板內 SHERLOCKZH 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613023.A.974.html">[問卦] 為什麼科技版那麼多神祕數字？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">readtyu</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%82%BA%E4%BB%80%E9%BA%BC%E7%A7%91%E6%8A%80%E7%89%88%E9%82%A3%E9%BA%BC%E5%A4%9A%E7%A5%9E%E7%A5%95%E6%95%B8%E5%AD%97%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Areadtyu">搜尋看板內 readtyu 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613023.A.DA6.html">[新聞] 老舊公寓居家照顧怎麼下樓取藥？陳時中：</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">chucky</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E5%AE%B6%E7%85%A7%E9%A1%A7%E6%80%8E%E9%BA%BC%E4%B8%8B%E6%A8%93%E5%8F%96%E8%97%A5%EF%BC%9F%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Achucky">搜尋看板內 chucky 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613042.A.5DF.html">Re: [新聞] 北市4/25起國高中遠距教學 新北不跟進  </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">smalltwo</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E5%8C%97%E5%B8%824%2F25%E8%B5%B7%E5%9C%8B%E9%AB%98%E4%B8%AD%E9%81%A0%E8%B7%9D%E6%95%99%E5%AD%B8&#43;%E6%96%B0%E5%8C%97%E4%B8%8D%E8%B7%9F%E9%80%B2&#43;&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Asmalltwo">搜尋看板內 smalltwo 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613109.A.D1A.html">Re: [新聞] 老舊公寓居隔怎麼取物 陳時中：鑰匙綁繩</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">AZTEC</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E9%9A%94%E6%80%8E%E9%BA%BC%E5%8F%96%E7%89%A9&#43;%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%91%B0%E5%8C%99%E7%B6%81%E7%B9%A9">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAZTEC">搜尋看板內 AZTEC 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650613111.A.651.html">[新聞]   540萬→988萬！三重16坪公寓巧隔3房　</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">zeroBB</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;&#43;&#43;540%E8%90%AC%E2%86%92988%E8%90%AC%EF%BC%81%E4%B8%89%E9%87%8D16%E5%9D%AA%E5%85%AC%E5%AF%93%E5%B7%A7%E9%9A%943%E6%88%BF%E3%80%80">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AzeroBB">搜尋看板內 zeroBB 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1645455874.A.65E.html">[公告] 八卦板板規(2022.02.21)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282022.02.21%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/21</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">43</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650597362.A.E16.html">[公告] 近期建議都更換不一樣密碼 水桶&amp;改判</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E8%BF%91%E6%9C%9F%E5%BB%BA%E8%AD%B0%E9%83%BD%E6%9B%B4%E6%8F%9B%E4%B8%8D%E4%B8%80%E6%A8%A3%E5%AF%86%E7%A2%BC&#43;%E6%B0%B4%E6%A1%B6%26%E6%94%B9%E5%88%A4">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650603431.A.308.html">Fw: [公告] 請使用者採取建議措施保護帳號</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E8%AB%8B%E4%BD%BF%E7%94%A8%E8%80%85%E6%8E%A1%E5%8F%96%E5%BB%BA%E8%AD%B0%E6%8E%AA%E6%96%BD%E4%BF%9D%E8%AD%B7%E5%B8%B3%E8%99%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1650604537.A.F7B.html">[協尋] 4/21新竹新豐死亡車禍行車紀錄器</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">MINI52716</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;4%2F21%E6%96%B0%E7%AB%B9%E6%96%B0%E8%B1%90%E6%AD%BB%E4%BA%A1%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AMINI52716">搜尋看板內 MINI52716 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script type="text/javascript">(function(){window['__CF$cv$params']={r:'6ffcb46e79dc2049',m:'Q6tdWt8lrheAv3xRU_7PdHJ.SuNq_mzgdo.cCtyqMJM-1650613158-0-AYbTO7M+Nmhd2PPQROE4JQHWi4gzZ4yH+9gl2c3Sy7llZIZEUChLDkXZjINwcGHneYaU32QjSufFrgNrQwyobo+a7XM4uJ39n86AIEoXQjEC0jFPUjB40wiaUgDO9ng57Hwe63uVSIgbV5x+/Keibjo=',s:[0x72b28728ab,0x57848c6f4a],u:'/cdn-cgi/challenge-platform/h/g'}})();</script></body>
# </html>

# %% [markdown]
# ***

# %% [markdown]
# ### Step4. 以HTML標籤及屬性搜尋節點

# %% [markdown]
# ### soup物件包含了整個網頁的HTML程式碼，接下來利用BeautifulSoup套件進行節點的搜尋。

# %%
# 將網頁資料以html.parser
soup = BeautifulSoup(res.text, "html.parser")

# %% [markdown]
# ### 1. find()
#     - 只搜尋第一個符合條件的HTML節點，傳入要搜尋的標籤名稱

# %%
result = soup.find("div")
print(result)
# Out:
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>

# %% [markdown]
# ### 2. find_all()
#     - 搜尋所有符合條件的HTML節點，傳入要搜尋的標籤名稱
#     - 可以利用關鍵字參數(Keyword Argument)指定其屬性值。
#     - 由於執行結果可能會搜出許多的HTML內容，所以最後也可以利用limit關鍵字參數(Keyword Argument)限制搜尋的節點數量

# %%
result = soup.find_all("div", id="action-bar-container", limit=3)
print(result)
# Out:
# [<div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# <a class="btn" href="/man/Gossiping/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Gossiping/index39346.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# </div>
# </div>
# </div>]

# %% [markdown]
# ### 2.1 同時搜尋多個HTML標籤

# %%
result = soup.find_all(["div", "a"], limit=5)
print(result)
# Out:
# [<div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>, <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>, <a href="/bbs/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>, <a class="right small" href="/about.html">關於我們</a>]

# %% [markdown]
# ### 3. 搜尋子節點
# ### select_one()
#     - 當某一節點下只有單個子節點時，可以利用select_one()
# ### select()
#     - 當某一節點下有多個子節點時，可以利用select()

# %%
result = soup.find("div")

# %%
print(result)
# Out:
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>

# %%
print(result.select_one("a"))
# Out:
# <a href="/bbs/" id="logo">批踢踢實業坊</a>

# %%
print(result.select("a"))
# Out:
# [<a href="/bbs/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>, <a class="right small" href="/about.html">關於我們</a>, <a class="right small" href="/contact.html">聯絡資訊</a>]

# %% [markdown]
# ***

# %% [markdown]
# ### Step 5. 以CSS屬性搜尋節點
#     - 依據HTML的css屬性來進行節點的搜尋，需使用class_ 進行css屬性值的指定

# %% [markdown]
# ### 1. find()
#     - 搜尋第一個符合指定的HTML標籤及css屬性值的節點

# %%
result = soup.find("div", class_="r-ent")
print(result)
# Out:
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>

# %% [markdown]
# ### 2. find_all()
#     - 搜尋網頁中符合指定的HTML標籤及css屬性值的所有節點

# %%
result = soup.find_all("div", class_="r-ent", limit=3)
print(result)
# Out:
# [<div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
#
# 				(本文已被刪除) [golang]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">56</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
# </div>
# <div class="meta">
# <div class="author">mom10dollar</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%EF%BD%9C%E6%AC%A020%E8%90%AC%E5%84%9F300%E8%90%AC%E9%82%84%E4%B8%8D%E5%A4%A0%EF%BC%81%E7%89%B9%E6%88%B0%E5%A3%AB%E5%AE%98%E4%B8%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amom10dollar">搜尋看板內 mom10dollar 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>]

# %% [markdown]
# ### 3. select()
#     - 單純只想要透過css屬性值來進行HTML節點的搜尋

# %%
result = soup.select(".r-ent", limit=3)
print(result)
# Out:
# [<div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
#
# 				(本文已被刪除) [golang]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">56</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
# </div>
# <div class="meta">
# <div class="author">mom10dollar</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%EF%BD%9C%E6%AC%A020%E8%90%AC%E5%84%9F300%E8%90%AC%E9%82%84%E4%B8%8D%E5%A4%A0%EF%BC%81%E7%89%B9%E6%88%B0%E5%A3%AB%E5%AE%98%E4%B8%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amom10dollar">搜尋看板內 mom10dollar 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>]

# %% [markdown]
# ***

# %% [markdown]
# ### Step 6. 搜尋父節點
#     - 以上皆為向下的搜尋節點方式，如果想要從某一個節點向上搜尋，可以透過find_parent()跟find_parents()

# %%
result = soup.find("div", class_="title")
parents = result.find_parents("div")
print(parents)
# Out:
# [<div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>, <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
#
# 				(本文已被刪除) [golang]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">56</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
# </div>
# <div class="meta">
# <div class="author">mom10dollar</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%EF%BD%9C%E6%AC%A020%E8%90%AC%E5%84%9F300%E8%90%AC%E9%82%84%E4%B8%8D%E5%A4%A0%EF%BC%81%E7%89%B9%E6%88%B0%E5%A3%AB%E5%AE%98%E4%B8%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amom10dollar">搜尋看板內 mom10dollar 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612732.A.426.html">[新聞] 「以篩代隔」隔離保單賠不賠？ 業者說</a>
# </div>
# <div class="meta">
# <div class="author">wbsinger</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E3%80%8C%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%E3%80%8D%E9%9A%94%E9%9B%A2%E4%BF%9D%E5%96%AE%E8%B3%A0%E4%B8%8D%E8%B3%A0%EF%BC%9F+%E6%A5%AD%E8%80%85%E8%AA%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awbsinger">搜尋看板內 wbsinger 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612740.A.15A.html">[問卦] 養狗還是養小孩?</a>
# </div>
# <div class="meta">
# <div class="author">snowsummersp</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E9%A4%8A%E7%8B%97%E9%82%84%E6%98%AF%E9%A4%8A%E5%B0%8F%E5%AD%A9%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asnowsummersp">搜尋看板內 snowsummersp 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612824.A.CDE.html">Re: [問卦] 台灣的大學生到底在怕甚麼?????</a>
# </div>
# <div class="meta">
# <div class="author">papapapapapa</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E7%81%A3%E7%9A%84%E5%A4%A7%E5%AD%B8%E7%94%9F%E5%88%B0%E5%BA%95%E5%9C%A8%E6%80%95%E7%94%9A%E9%BA%BC%3F%3F%3F%3F%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Apapapapapapa">搜尋看板內 papapapapapa 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612863.A.F2F.html">[問卦] 用無人機外送可行嗎？</a>
# </div>
# <div class="meta">
# <div class="author">ronnyvvang</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%94%A8%E7%84%A1%E4%BA%BA%E6%A9%9F%E5%A4%96%E9%80%81%E5%8F%AF%E8%A1%8C%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aronnyvvang">搜尋看板內 ronnyvvang 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612898.A.B1F.html">[問卦] 是不是要等年輕人死光了再來打疫苗?</a>
# </div>
# <div class="meta">
# <div class="author">GoogleTaiwan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%98%AF%E4%B8%8D%E6%98%AF%E8%A6%81%E7%AD%89%E5%B9%B4%E8%BC%95%E4%BA%BA%E6%AD%BB%E5%85%89%E4%BA%86%E5%86%8D%E4%BE%86%E6%89%93%E7%96%AB%E8%8B%97%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AGoogleTaiwan">搜尋看板內 GoogleTaiwan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612930.A.705.html">Re: [爆卦] 本土+3766 類官方粗暴版本（轉）</a>
# </div>
# <div class="meta">
# <div class="author">devidevi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E7%88%86%E5%8D%A6%5D+%E6%9C%AC%E5%9C%9F%2B3766+%E9%A1%9E%E5%AE%98%E6%96%B9%E7%B2%97%E6%9A%B4%E7%89%88%E6%9C%AC%EF%BC%88%E8%BD%89%EF%BC%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Adevidevi">搜尋看板內 devidevi 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612986.A.0A8.html">[新聞] 雙北逾3萬人居隔！打3劑｢以篩代隔｣擬擴</a>
# </div>
# <div class="meta">
# <div class="author">zenmeke</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E9%9B%99%E5%8C%97%E9%80%BE3%E8%90%AC%E4%BA%BA%E5%B1%85%E9%9A%94%EF%BC%81%E6%89%933%E5%8A%91%EF%BD%A2%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%EF%BD%A3%E6%93%AC%E6%93%B4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Azenmeke">搜尋看板內 zenmeke 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612998.A.5F5.html">Re: [問卦] 台鐵員工5/1憑啥以勞工名義合理罷工</a>
# </div>
# <div class="meta">
# <div class="author">alvptt</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E9%90%B5%E5%93%A1%E5%B7%A55%2F1%E6%86%91%E5%95%A5%E4%BB%A5%E5%8B%9E%E5%B7%A5%E5%90%8D%E7%BE%A9%E5%90%88%E7%90%86%E7%BD%B7%E5%B7%A5">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalvptt">搜尋看板內 alvptt 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613014.A.663.html">[問卦] 何不用氣球將病患送醫跟送物資就好？</a>
# </div>
# <div class="meta">
# <div class="author">TPAsavelove</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E4%BD%95%E4%B8%8D%E7%94%A8%E6%B0%A3%E7%90%83%E5%B0%87%E7%97%85%E6%82%A3%E9%80%81%E9%86%AB%E8%B7%9F%E9%80%81%E7%89%A9%E8%B3%87%E5%B0%B1%E5%A5%BD%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ATPAsavelove">搜尋看板內 TPAsavelove 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613015.A.431.html">[問卦] 老闆反應永遠慢半拍的八卦？</a>
# </div>
# <div class="meta">
# <div class="author">SHERLOCKZH</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E8%80%81%E9%97%86%E5%8F%8D%E6%87%89%E6%B0%B8%E9%81%A0%E6%85%A2%E5%8D%8A%E6%8B%8D%E7%9A%84%E5%85%AB%E5%8D%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASHERLOCKZH">搜尋看板內 SHERLOCKZH 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613023.A.974.html">[問卦] 為什麼科技版那麼多神祕數字？</a>
# </div>
# <div class="meta">
# <div class="author">readtyu</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%82%BA%E4%BB%80%E9%BA%BC%E7%A7%91%E6%8A%80%E7%89%88%E9%82%A3%E9%BA%BC%E5%A4%9A%E7%A5%9E%E7%A5%95%E6%95%B8%E5%AD%97%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Areadtyu">搜尋看板內 readtyu 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613023.A.DA6.html">[新聞] 老舊公寓居家照顧怎麼下樓取藥？陳時中：</a>
# </div>
# <div class="meta">
# <div class="author">chucky</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E5%AE%B6%E7%85%A7%E9%A1%A7%E6%80%8E%E9%BA%BC%E4%B8%8B%E6%A8%93%E5%8F%96%E8%97%A5%EF%BC%9F%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Achucky">搜尋看板內 chucky 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613042.A.5DF.html">Re: [新聞] 北市4/25起國高中遠距教學 新北不跟進  </a>
# </div>
# <div class="meta">
# <div class="author">smalltwo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%8C%97%E5%B8%824%2F25%E8%B5%B7%E5%9C%8B%E9%AB%98%E4%B8%AD%E9%81%A0%E8%B7%9D%E6%95%99%E5%AD%B8+%E6%96%B0%E5%8C%97%E4%B8%8D%E8%B7%9F%E9%80%B2++">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asmalltwo">搜尋看板內 smalltwo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613109.A.D1A.html">Re: [新聞] 老舊公寓居隔怎麼取物 陳時中：鑰匙綁繩</a>
# </div>
# <div class="meta">
# <div class="author">AZTEC</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E9%9A%94%E6%80%8E%E9%BA%BC%E5%8F%96%E7%89%A9+%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%91%B0%E5%8C%99%E7%B6%81%E7%B9%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AAZTEC">搜尋看板內 AZTEC 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613111.A.651.html">[新聞]   540萬→988萬！三重16坪公寓巧隔3房　</a>
# </div>
# <div class="meta">
# <div class="author">zeroBB</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+++540%E8%90%AC%E2%86%92988%E8%90%AC%EF%BC%81%E4%B8%89%E9%87%8D16%E5%9D%AA%E5%85%AC%E5%AF%93%E5%B7%A7%E9%9A%943%E6%88%BF%E3%80%80">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AzeroBB">搜尋看板內 zeroBB 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1645455874.A.65E.html">[公告] 八卦板板規(2022.02.21)</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282022.02.21%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/21</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">43</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650597362.A.E16.html">[公告] 近期建議都更換不一樣密碼 水桶&amp;改判</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%BF%91%E6%9C%9F%E5%BB%BA%E8%AD%B0%E9%83%BD%E6%9B%B4%E6%8F%9B%E4%B8%8D%E4%B8%80%E6%A8%A3%E5%AF%86%E7%A2%BC+%E6%B0%B4%E6%A1%B6%26%E6%94%B9%E5%88%A4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650603431.A.308.html">Fw: [公告] 請使用者採取建議措施保護帳號</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%AB%8B%E4%BD%BF%E7%94%A8%E8%80%85%E6%8E%A1%E5%8F%96%E5%BB%BA%E8%AD%B0%E6%8E%AA%E6%96%BD%E4%BF%9D%E8%AD%B7%E5%B8%B3%E8%99%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650604537.A.F7B.html">[協尋] 4/21新竹新豐死亡車禍行車紀錄器</a>
# </div>
# <div class="meta">
# <div class="author">MINI52716</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+4%2F21%E6%96%B0%E7%AB%B9%E6%96%B0%E8%B1%90%E6%AD%BB%E4%BA%A1%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AMINI52716">搜尋看板內 MINI52716 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>, <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# <a class="btn" href="/man/Gossiping/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Gossiping/index39346.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# </div>
# <div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
#
# 				(本文已被刪除) [golang]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">56</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
# </div>
# <div class="meta">
# <div class="author">mom10dollar</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%EF%BD%9C%E6%AC%A020%E8%90%AC%E5%84%9F300%E8%90%AC%E9%82%84%E4%B8%8D%E5%A4%A0%EF%BC%81%E7%89%B9%E6%88%B0%E5%A3%AB%E5%AE%98%E4%B8%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amom10dollar">搜尋看板內 mom10dollar 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612732.A.426.html">[新聞] 「以篩代隔」隔離保單賠不賠？ 業者說</a>
# </div>
# <div class="meta">
# <div class="author">wbsinger</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E3%80%8C%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%E3%80%8D%E9%9A%94%E9%9B%A2%E4%BF%9D%E5%96%AE%E8%B3%A0%E4%B8%8D%E8%B3%A0%EF%BC%9F+%E6%A5%AD%E8%80%85%E8%AA%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awbsinger">搜尋看板內 wbsinger 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612740.A.15A.html">[問卦] 養狗還是養小孩?</a>
# </div>
# <div class="meta">
# <div class="author">snowsummersp</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E9%A4%8A%E7%8B%97%E9%82%84%E6%98%AF%E9%A4%8A%E5%B0%8F%E5%AD%A9%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asnowsummersp">搜尋看板內 snowsummersp 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612824.A.CDE.html">Re: [問卦] 台灣的大學生到底在怕甚麼?????</a>
# </div>
# <div class="meta">
# <div class="author">papapapapapa</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E7%81%A3%E7%9A%84%E5%A4%A7%E5%AD%B8%E7%94%9F%E5%88%B0%E5%BA%95%E5%9C%A8%E6%80%95%E7%94%9A%E9%BA%BC%3F%3F%3F%3F%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Apapapapapapa">搜尋看板內 papapapapapa 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612863.A.F2F.html">[問卦] 用無人機外送可行嗎？</a>
# </div>
# <div class="meta">
# <div class="author">ronnyvvang</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%94%A8%E7%84%A1%E4%BA%BA%E6%A9%9F%E5%A4%96%E9%80%81%E5%8F%AF%E8%A1%8C%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aronnyvvang">搜尋看板內 ronnyvvang 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612898.A.B1F.html">[問卦] 是不是要等年輕人死光了再來打疫苗?</a>
# </div>
# <div class="meta">
# <div class="author">GoogleTaiwan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%98%AF%E4%B8%8D%E6%98%AF%E8%A6%81%E7%AD%89%E5%B9%B4%E8%BC%95%E4%BA%BA%E6%AD%BB%E5%85%89%E4%BA%86%E5%86%8D%E4%BE%86%E6%89%93%E7%96%AB%E8%8B%97%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AGoogleTaiwan">搜尋看板內 GoogleTaiwan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612930.A.705.html">Re: [爆卦] 本土+3766 類官方粗暴版本（轉）</a>
# </div>
# <div class="meta">
# <div class="author">devidevi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E7%88%86%E5%8D%A6%5D+%E6%9C%AC%E5%9C%9F%2B3766+%E9%A1%9E%E5%AE%98%E6%96%B9%E7%B2%97%E6%9A%B4%E7%89%88%E6%9C%AC%EF%BC%88%E8%BD%89%EF%BC%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Adevidevi">搜尋看板內 devidevi 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612986.A.0A8.html">[新聞] 雙北逾3萬人居隔！打3劑｢以篩代隔｣擬擴</a>
# </div>
# <div class="meta">
# <div class="author">zenmeke</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E9%9B%99%E5%8C%97%E9%80%BE3%E8%90%AC%E4%BA%BA%E5%B1%85%E9%9A%94%EF%BC%81%E6%89%933%E5%8A%91%EF%BD%A2%E4%BB%A5%E7%AF%A9%E4%BB%A3%E9%9A%94%EF%BD%A3%E6%93%AC%E6%93%B4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Azenmeke">搜尋看板內 zenmeke 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650612998.A.5F5.html">Re: [問卦] 台鐵員工5/1憑啥以勞工名義合理罷工</a>
# </div>
# <div class="meta">
# <div class="author">alvptt</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E9%90%B5%E5%93%A1%E5%B7%A55%2F1%E6%86%91%E5%95%A5%E4%BB%A5%E5%8B%9E%E5%B7%A5%E5%90%8D%E7%BE%A9%E5%90%88%E7%90%86%E7%BD%B7%E5%B7%A5">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalvptt">搜尋看板內 alvptt 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613014.A.663.html">[問卦] 何不用氣球將病患送醫跟送物資就好？</a>
# </div>
# <div class="meta">
# <div class="author">TPAsavelove</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E4%BD%95%E4%B8%8D%E7%94%A8%E6%B0%A3%E7%90%83%E5%B0%87%E7%97%85%E6%82%A3%E9%80%81%E9%86%AB%E8%B7%9F%E9%80%81%E7%89%A9%E8%B3%87%E5%B0%B1%E5%A5%BD%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ATPAsavelove">搜尋看板內 TPAsavelove 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613015.A.431.html">[問卦] 老闆反應永遠慢半拍的八卦？</a>
# </div>
# <div class="meta">
# <div class="author">SHERLOCKZH</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E8%80%81%E9%97%86%E5%8F%8D%E6%87%89%E6%B0%B8%E9%81%A0%E6%85%A2%E5%8D%8A%E6%8B%8D%E7%9A%84%E5%85%AB%E5%8D%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASHERLOCKZH">搜尋看板內 SHERLOCKZH 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613023.A.974.html">[問卦] 為什麼科技版那麼多神祕數字？</a>
# </div>
# <div class="meta">
# <div class="author">readtyu</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%82%BA%E4%BB%80%E9%BA%BC%E7%A7%91%E6%8A%80%E7%89%88%E9%82%A3%E9%BA%BC%E5%A4%9A%E7%A5%9E%E7%A5%95%E6%95%B8%E5%AD%97%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Areadtyu">搜尋看板內 readtyu 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613023.A.DA6.html">[新聞] 老舊公寓居家照顧怎麼下樓取藥？陳時中：</a>
# </div>
# <div class="meta">
# <div class="author">chucky</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E5%AE%B6%E7%85%A7%E9%A1%A7%E6%80%8E%E9%BA%BC%E4%B8%8B%E6%A8%93%E5%8F%96%E8%97%A5%EF%BC%9F%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Achucky">搜尋看板內 chucky 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613042.A.5DF.html">Re: [新聞] 北市4/25起國高中遠距教學 新北不跟進  </a>
# </div>
# <div class="meta">
# <div class="author">smalltwo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%8C%97%E5%B8%824%2F25%E8%B5%B7%E5%9C%8B%E9%AB%98%E4%B8%AD%E9%81%A0%E8%B7%9D%E6%95%99%E5%AD%B8+%E6%96%B0%E5%8C%97%E4%B8%8D%E8%B7%9F%E9%80%B2++">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asmalltwo">搜尋看板內 smalltwo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613109.A.D1A.html">Re: [新聞] 老舊公寓居隔怎麼取物 陳時中：鑰匙綁繩</a>
# </div>
# <div class="meta">
# <div class="author">AZTEC</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%80%81%E8%88%8A%E5%85%AC%E5%AF%93%E5%B1%85%E9%9A%94%E6%80%8E%E9%BA%BC%E5%8F%96%E7%89%A9+%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%91%B0%E5%8C%99%E7%B6%81%E7%B9%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AAZTEC">搜尋看板內 AZTEC 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650613111.A.651.html">[新聞]   540萬→988萬！三重16坪公寓巧隔3房　</a>
# </div>
# <div class="meta">
# <div class="author">zeroBB</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+++540%E8%90%AC%E2%86%92988%E8%90%AC%EF%BC%81%E4%B8%89%E9%87%8D16%E5%9D%AA%E5%85%AC%E5%AF%93%E5%B7%A7%E9%9A%943%E6%88%BF%E3%80%80">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AzeroBB">搜尋看板內 zeroBB 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1645455874.A.65E.html">[公告] 八卦板板規(2022.02.21)</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282022.02.21%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/21</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">43</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650597362.A.E16.html">[公告] 近期建議都更換不一樣密碼 水桶&amp;改判</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%BF%91%E6%9C%9F%E5%BB%BA%E8%AD%B0%E9%83%BD%E6%9B%B4%E6%8F%9B%E4%B8%8D%E4%B8%80%E6%A8%A3%E5%AF%86%E7%A2%BC+%E6%B0%B4%E6%A1%B6%26%E6%94%B9%E5%88%A4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650603431.A.308.html">Fw: [公告] 請使用者採取建議措施保護帳號</a>
# </div>
# <div class="meta">
# <div class="author">ubcs</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%AB%8B%E4%BD%BF%E7%94%A8%E8%80%85%E6%8E%A1%E5%8F%96%E5%BB%BA%E8%AD%B0%E6%8E%AA%E6%96%BD%E4%BF%9D%E8%AD%B7%E5%B8%B3%E8%99%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1650604537.A.F7B.html">[協尋] 4/21新竹新豐死亡車禍行車紀錄器</a>
# </div>
# <div class="meta">
# <div class="author">MINI52716</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+4%2F21%E6%96%B0%E7%AB%B9%E6%96%B0%E8%B1%90%E6%AD%BB%E4%BA%A1%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AMINI52716">搜尋看板內 MINI52716 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
# </div>]

# %% [markdown]
# ***

# %% [markdown]
# ### Step 7. 搜尋前、後節點
#     - 在同一層級的節點，想要搜尋前一個節點，可以透過find_previous_siblings()
#     - 在同一層級的節點，想要搜尋後一個節點，可以透過find_next_siblings()

# %%
#print(res.text)

# %%
result = soup.find("div", class_="title")
previous_node = result.find_previous_siblings("div")
print(previous_node)
# Out:
# [<div class="nrec"></div>]

# %%
result = soup.find("div", class_="title")
previous_node = result.find_next_siblings("div")
print(previous_node)
# Out:
# [<div class="meta">
# <div class="author">Skyblueway</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%8D%E5%8F%AA3%E5%8D%83%E8%90%AC%E5%8A%91%E5%BF%AB%E7%AF%A9%E4%B8%8B%E5%91%A8%E5%88%B0%E8%B2%A8%E3%80%80%E9%99%B3%E6%99%82%E4%B8%AD%EF%BC%9A%E9%99%B8%E7%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ASkyblueway">搜尋看板內 Skyblueway 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/22</div>
# <div class="mark"></div>
# </div>]

# %% [markdown]
# ***

# %% [markdown]
# ### Step 8. 取得屬性值
#     - 如果想要取得某一個節點中的屬性值，則可以利用BeautifulSoup套件的get()

# %%
result = soup.find_all("div", class_="r-ent")
for title in result:
    print(title.select_one("a"))
# Out:
# <a href="/bbs/Gossiping/M.1650612668.A.665.html">[新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續</a>
# None
# <a href="/bbs/Gossiping/M.1650612703.A.0A3.html">Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不</a>
# <a href="/bbs/Gossiping/M.1650612732.A.426.html">[新聞] 「以篩代隔」隔離保單賠不賠？ 業者說</a>
# <a href="/bbs/Gossiping/M.1650612740.A.15A.html">[問卦] 養狗還是養小孩?</a>
# <a href="/bbs/Gossiping/M.1650612824.A.CDE.html">Re: [問卦] 台灣的大學生到底在怕甚麼?????</a>
# <a href="/bbs/Gossiping/M.1650612863.A.F2F.html">[問卦] 用無人機外送可行嗎？</a>
# <a href="/bbs/Gossiping/M.1650612898.A.B1F.html">[問卦] 是不是要等年輕人死光了再來打疫苗?</a>
# <a href="/bbs/Gossiping/M.1650612930.A.705.html">Re: [爆卦] 本土+3766 類官方粗暴版本（轉）</a>
# <a href="/bbs/Gossiping/M.1650612986.A.0A8.html">[新聞] 雙北逾3萬人居隔！打3劑｢以篩代隔｣擬擴</a>
# <a href="/bbs/Gossiping/M.1650612998.A.5F5.html">Re: [問卦] 台鐵員工5/1憑啥以勞工名義合理罷工</a>
# <a href="/bbs/Gossiping/M.1650613014.A.663.html">[問卦] 何不用氣球將病患送醫跟送物資就好？</a>
# <a href="/bbs/Gossiping/M.1650613015.A.431.html">[問卦] 老闆反應永遠慢半拍的八卦？</a>
# <a href="/bbs/Gossiping/M.1650613023.A.974.html">[問卦] 為什麼科技版那麼多神祕數字？</a>
# <a href="/bbs/Gossiping/M.1650613023.A.DA6.html">[新聞] 老舊公寓居家照顧怎麼下樓取藥？陳時中：</a>
# <a href="/bbs/Gossiping/M.1650613042.A.5DF.html">Re: [新聞] 北市4/25起國高中遠距教學 新北不跟進  </a>
# <a href="/bbs/Gossiping/M.1650613109.A.D1A.html">Re: [新聞] 老舊公寓居隔怎麼取物 陳時中：鑰匙綁繩</a>
# <a href="/bbs/Gossiping/M.1650613111.A.651.html">[新聞]   540萬→988萬！三重16坪公寓巧隔3房　</a>
# <a href="/bbs/Gossiping/M.1645455874.A.65E.html">[公告] 八卦板板規(2022.02.21)</a>
# <a href="/bbs/Gossiping/M.1650597362.A.E16.html">[公告] 近期建議都更換不一樣密碼 水桶&amp;改判</a>
# <a href="/bbs/Gossiping/M.1650603431.A.308.html">Fw: [公告] 請使用者採取建議措施保護帳號</a>
# <a href="/bbs/Gossiping/M.1650604537.A.F7B.html">[協尋] 4/21新竹新豐死亡車禍行車紀錄器</a>

# %%
result = soup.find_all("div", class_="r-ent")
for title in result:
    if title.select_one("a") != None:
        print(title.select_one("a").get("href"), " : ", title.select_one("a").text)
        #print(title.select_one("a").get("href"), " : ", title.select_one("a").getText())
# Out:
# /bbs/Gossiping/M.1650612668.A.665.html  :  [新聞] 不只3千萬劑快篩下周到貨　陳時中：陸續
# /bbs/Gossiping/M.1650612703.A.0A3.html  :  Re: [新聞] 獨家｜欠20萬償300萬還不夠！特戰士官不
# /bbs/Gossiping/M.1650612732.A.426.html  :  [新聞] 「以篩代隔」隔離保單賠不賠？ 業者說
# /bbs/Gossiping/M.1650612740.A.15A.html  :  [問卦] 養狗還是養小孩?
# /bbs/Gossiping/M.1650612824.A.CDE.html  :  Re: [問卦] 台灣的大學生到底在怕甚麼?????
# /bbs/Gossiping/M.1650612863.A.F2F.html  :  [問卦] 用無人機外送可行嗎？
# /bbs/Gossiping/M.1650612898.A.B1F.html  :  [問卦] 是不是要等年輕人死光了再來打疫苗?
# /bbs/Gossiping/M.1650612930.A.705.html  :  Re: [爆卦] 本土+3766 類官方粗暴版本（轉）
# /bbs/Gossiping/M.1650612986.A.0A8.html  :  [新聞] 雙北逾3萬人居隔！打3劑｢以篩代隔｣擬擴
# /bbs/Gossiping/M.1650612998.A.5F5.html  :  Re: [問卦] 台鐵員工5/1憑啥以勞工名義合理罷工
# /bbs/Gossiping/M.1650613014.A.663.html  :  [問卦] 何不用氣球將病患送醫跟送物資就好？
# /bbs/Gossiping/M.1650613015.A.431.html  :  [問卦] 老闆反應永遠慢半拍的八卦？
# /bbs/Gossiping/M.1650613023.A.974.html  :  [問卦] 為什麼科技版那麼多神祕數字？
# /bbs/Gossiping/M.1650613023.A.DA6.html  :  [新聞] 老舊公寓居家照顧怎麼下樓取藥？陳時中：
# /bbs/Gossiping/M.1650613042.A.5DF.html  :  Re: [新聞] 北市4/25起國高中遠距教學 新北不跟進
# /bbs/Gossiping/M.1650613109.A.D1A.html  :  Re: [新聞] 老舊公寓居隔怎麼取物 陳時中：鑰匙綁繩
# /bbs/Gossiping/M.1650613111.A.651.html  :  [新聞]   540萬→988萬！三重16坪公寓巧隔3房
# /bbs/Gossiping/M.1645455874.A.65E.html  :  [公告] 八卦板板規(2022.02.21)
# /bbs/Gossiping/M.1650597362.A.E16.html  :  [公告] 近期建議都更換不一樣密碼 水桶&改判
# /bbs/Gossiping/M.1650603431.A.308.html  :  Fw: [公告] 請使用者採取建議措施保護帳號
# /bbs/Gossiping/M.1650604537.A.F7B.html  :  [協尋] 4/21新竹新豐死亡車禍行車紀錄器
